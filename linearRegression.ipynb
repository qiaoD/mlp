# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets

# %%
#
diabetes = datasets.load_diabetes()
diabetes_x = diabetes.data[:,np.newaxis,2]

X = diabetes_x[:40]
x_test = diabetes_x[-40:]
Y = diabetes.target[:40]
y_test = diabetes.target[-40:]
X = np.array([1, 2, 4])
Y = np.array([2, 4, 8])

# %%
plt.scatter(X, Y)
plt.show()

# %%
def predict(X):
    return W * X + b

# %%
W = np.random.randn()
b = np.random.randn()
print(W)
print(b)
# Out:
# -0.23461252411597577
# 1.9607694282424133

# %%
def cost(X, Y):
    N = float(len(X))
    return 1/N * np.sum((predict(X) - Y) ** 2)

# %%
rate = .01

# %%
for j in range(1000):
    for i in range(len(X)):
        W = W + rate * (Y[i] - predict(X[i])) * X[i]  
        b = b + rate * (Y[i] - predict(X[i]))
    plt.scatter(X, Y)
    plt.plot(X, predict(X))
plt.show()
print(cost(X, Y))
# Out:
# 2.7600589553e-06

# %%
plt.scatter(X, Y)
plt.plot(X , predict(X))
plt.show()

# %%
print(Y[2])
# Out:
# 8

# %%
print(predict(X[2]))
# Out:
# 7.99887519216
